# %% [markdown]
# <a href="https://colab.research.google.com/github/Harivamsh2005/competitive_programming/blob/main/A1_MONDAYipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  def maxMeetings(meetings):
    meetings.sort(key=lambda x: x[1])

    count = 0
    lastEnd = -1

    for start, end in meetings:
        if start >= lastEnd:   # change here
            count += 1
            lastEnd = end

    return count


t = int(input())

for _ in range(t):
    n = int(input())
    meetings = []

    for _ in range(n):
        startTime, endTime = map(int, input().split())
        meetings.append((startTime, endTime))

    print(maxMeetings(meetings))
# Out:
# 1
# 3
# 1 3
# 2 4
# 3 5
# 2
